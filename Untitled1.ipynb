# %%
# Installing the sentence-transformers library
# !pip install -U sentence-transformers

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sentence_transformers import SentenceTransformer, util

# Loading the model (this might take a few seconds to download)
model = SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
# 10 sentences across 3 topics: Cricket, Cooking, and Cybersecurity
my_sentences = [
    "The opening batsman played a beautiful cover drive for four.",
    "Spinners are usually more effective on dry, dusty pitches.",
    "Winning the toss is a huge advantage in day-night matches.",
    "A pinch of salt can really bring out the sweetness in chocolate.",
    "Slowly sauté the onions until they turn a golden brown color.",
    "Always let the meat rest for a few minutes after grilling it.",
    "Fresh herbs like parsley and cilantro add a nice finishing touch.",
    "Using a strong password isn't enough; you need 2FA enabled.",
    "Phishing links in emails are a common way to steal credentials.",
    "Hackers often exploit unpatched software to gain system access."
]

# Generating embeddings for each sentence
embeddings = model.encode(my_sentences)
print("Embeddings generated successfully!")
# Out:
# Embeddings generated successfully!

# %%
# Calculating the 10x10 cosine similarity matrix
sim_matrix = util.cos_sim(embeddings, embeddings)

# Plotting the heatmap using Seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(sim_matrix, annot=True, cmap='Blues', fmt=".2f")
plt.title("Semantic Similarity Heatmap")
plt.show()

# %%
# New query sentence
query_text = "The bowler took three wickets in one over"
query_vec = model.encode(query_text)

# Finding the top 2 most similar sentences
results = util.semantic_search(query_vec, embeddings, top_k=2)

print(f"Input Query: {query_text}")
print("-" * 40)
for res in results[0]:
    sentence = my_sentences[res['corpus_id']]
    score = res['score']
    print(f"Match: {sentence} (Score: {score:.4f})")
# Out:
# Input Query: The bowler took three wickets in one over
# ----------------------------------------
# Match: The opening batsman played a beautiful cover drive for four. (Score: 0.5203)
# Match: Winning the toss is a huge advantage in day-night matches. (Score: 0.3236)
